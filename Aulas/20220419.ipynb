# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator,ClassifierMixin
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
import random

DEBUG = 'DEBUG: '

# %%
def criaDataset(n=20,slop=[2,1],intercept=-0.4):
  X = np.random.uniform(size=(n,2))
  AUX = np.multiply(X,slop) - [0,intercept]
  y = (AUX[:,0] > AUX[:,1])*2 -1
  return X,y

def criaDatasetBlobs(n=1000,n_classes=4,std=0.02):
  X,y = make_blobs(n_samples=n,centers=n_classes,center_box=(0,1.0),cluster_std=0.02)
  return X,y

def criaDatasetXOR(n=100):
  X,y = make_blobs(n_samples=n,centers=[[0,0],[1,0],[1,1],[0,1]],cluster_std=0.1)
  y =np.array(y%2,dtype=int)
  return X,y

def plotDataset(X,y):
  plt.xlabel('X1')
  plt.ylabel('X2')
  for k in set(y):
    plt.plot(X[:,0][y==k],
             X[:,1][y==k],
             "o",alpha=0.3)

# %%
def define_axes(X):
  min1,max1 = X[:,0].min(), X[:,0].max()
  min2,max2 = X[:,1].min(), X[:,1].max()
  return [min1 -0.1, max1 +0.1,min2 -0.1,max2+0.1]

def define_axes2(X):
  minmaxs = []
  for i in range(X.shape[1]):
    minmaxs.append(np.array([X[:,i].min(), X[:,i].max()]))
  
  return np.array(minmaxs)
    

def plotPredictions(clf,X,dims=[0,1]):
  axes = define_axes(X)
  x0s = np.linspace(axes[0],axes[1],100)
  x1s = np.linspace(axes[2],axes[3],100)
  x0,x1 = np.meshgrid(x0s,x1s)
  X_ = np.c_[x0.ravel(),x1.ravel()]
  print(DEBUG,X_.shape)
  ypred = clf.predict(X_).reshape(x0.shape)
  print(DEBUG,X_.shape,x0.shape,x1.shape,ypred.shape)
  plt.contourf(x0,x1,ypred,cmap=plt.cm.brg,alpha=0.2)

def plotPredictions2(clf,X,dims=[0,1],resolution=50):
  axes = define_axes2(X)
  xs = []
  for i in range(axes.shape[0]):
    #print(DEBUG,i)
    xs.append(np.linspace(axes[i,0],axes[i,1],resolution))

  xt1 = np.meshgrid(*xs)
  #return xt1
  xt2 = [x.ravel() for x in xt1]

  X_ = np.c_[xt2].T
  #return X_
  print(DEBUG,X_.shape)
  ypred = clf.predict(X_).reshape(xt1[dims[0]].shape)
  print(DEBUG,X_.shape,xt1[dims[0],dims].shape,xt1[dims[1],dims].shape,ypred[dims].shape)
  plt.contourf(xt1[dims[0],dims],xt1[dims[1],dims],ypred[dims],cmap=plt.cm.brg,alpha=0.2)
  #x0s = np.linspace(axes[0],axes[1],100)
  #x1s = np.linspace(axes[2],axes[3],100)
  #x0,x1 = np.meshgrid(x0s,x1s)
  #X_ = np.c_[x0.ravel(),x1.ravel()]
  #ypred = clf.predict(X_).reshape(x0.shape)
  #plt.contourf(x0,x1,ypred,cmap=plt.cm.brg,alpha=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
data = load_iris()
X = StandardScaler().fit_transform(data.data)[:]
y = data.target

#X,y = criaDatasetBlobs(200)
clf = KNeighborsClassifier()
clf.fit(X,y)
#plotDataset(X,y)
plotPredictions2(clf,X)[0][0,0,:,:].shape
# Out:
# (50, 50)

# %%
from abc import ABC, abstractmethod,abstractstaticmethod
from scipy.special import expit
from sklearn.preprocessing import label_binarize

def sign(a):
  return (a>=0)*2-1

def tanh(a):
  return expit(a)*2 -1

#tanh = lambda a: expit(a)*2 -1

def accuracy(yactual,ypred):
  return sum(yactual==ypred)/len(yactual)


class TrainingAlgorithm(ABC):
  
  @abstractmethod
  def getW(self,X,y):
    pass

class PseudoInversaReg(TrainingAlgorithm):
  def __init__(self,regularization=0,history=[0]):
    self.history = history
    self.regularization = regularization
    
  def getW(self,X,y):
    w = np.linalg.inv(X.T @ X + np.identity(X.shape[1])*self.regularization) @ X.T @ y
    return w

class ELM(BaseEstimator,ClassifierMixin):
  def __init__ (self,n_hidden=10,regularization=0):
    self.n_hidden=n_hidden
    self.regularization = regularization
    self.activation = tanh
    self.training_algorithm = PseudoInversaReg(regularization=regularization)
    self.wih = None
    self.who = None
  
  def encode_labels(self,y):
    self.labels = list(set(y))
    return label_binarize(y,classes=self.labels)*2 -1
  
  def fit(self,X,y):
    Xb = ELM.includeBias(X)
    self.wih = np.random.uniform(-1,1,size=(Xb.shape[1],self.n_hidden)) #-1 a 1 com threshold em 0
    print(DEBUG,  Xb.shape, self.wih.shape)
    H = self.activation(Xb @ self.wih)
    Hb = ELM.includeBias(H)
    #yhot = self.encode_labels(y)
    self.who = self.training_algorithm.getW(Hb,y)#yhot)  

    return self
  
  def predict(self,X,y=None):
    Xb = ELM.includeBias(X)
    print(DEBUG,  Xb.shape, self.wih.shape)
    H = self.activation(Xb @ self.wih)
    Hb = ELM.includeBias(H)
    a = Hb @ self.who
    return a
    
    if self.who.shape[1] == 1:
      idx = np.array(a>0,dtype=int).reshape((-1,))
    else:
      idx = np.argmax(a,axis=1)

    ypred = np.array([self.labels[i] for i in idx])
    return ypred

  @staticmethod
  def includeBias(X):
    bias = np.ones((X.shape[0],1))
    #print("DEBUG: ",X.shape,bias)
    Xb = np.concatenate((bias,X),axis=1)
    #print("DEBUG: ",Xb.shape)
    return Xb

class MLP(BaseEstimator,ClassifierMixin):
  def __init__ (self,algorithm=ELM(n_hidden=50,regularization=0.1)):
    self.algorithm = algorithm
  
  def encode_labels(self,y):
    self.labels = list(set(y))
    return label_binarize(y,classes=self.labels)*2 -1
  
  def fit(self,X,y):
    yhot = self.encode_labels(y)
    self.algorithm.fit(X,yhot)
    return self
  
  def predict(self,X,y=None):
    a = self.algorithm.predict(X,y)
    
    if self.algorithm.who.shape[1] == 1:
      idx = np.array(a>0,dtype=int).reshape((-1,))
    else:
      idx = np.argmax(a,axis=1)

    ypred = np.array([self.labels[i] for i in idx])
    return ypred

# %%
Xtr,ytr = criaDatasetXOR(200)
clf = MLP()
clf.fit(Xtr,ytr)

plotPredictions(clf,Xtr)
#plt.show()

Xte,yte = criaDatasetXOR(10000)
plotDataset(Xte,yte)
plotDataset(Xtr,ytr)
plotPredictions(clf,Xtr)
# Out:
# DEBUG:  (200, 3) (3, 50)
# DEBUG:  (10000, 3) (3, 50)
# DEBUG:  (10000, 3) (3, 50)

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
data = load_iris()
X = StandardScaler().fit_transform(data.data)[:,[1,3]]
y = data.target

clf = ELM(n_hidden=50,regularization=0.1)
clf.fit(X,y)

print(DEBUG, X.shape)
plotPredictions(clf,X)
plotDataset(X,y)
# Out:
# DEBUG:  (150, 3) (3, 50)
# DEBUG:  (150, 2)
# DEBUG:  (10000, 3) (3, 50)
